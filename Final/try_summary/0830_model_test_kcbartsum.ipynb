# %%
import os
import pandas as pd
import torch
import re
from tqdm import tqdm
from soynlp.tokenizer import LTokenizer
from soynlp.normalizer import repeat_normalize
from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration, BertTokenizer, BertForSequenceClassification
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# GPU 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 데이터셋 로드 및 전처리
file_path = './외국음식전문점.csv'
df = pd.read_csv(file_path)
df['content'] = df['content'].fillna('')
text_data = df['content'].tolist()

# 전처리 함수 정의
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^가-힣\s]', '', text)
    text = repeat_normalize(text, num_repeats=2)
    stopwords = ['이', '그', '저', '의', '을', '를', '은', '는', '에', '와', '과', '도', '으로', '그리고', '하지만', '그래서']
    text = ' '.join([word for word in text.split() if word not in stopwords])
    return text.strip()

preprocessed_data = [preprocess_text(review) for review in text_data]

# 카테고리 분류 함수
categories = ['맛', '가격', '서비스', '분위기']
category_keywords = {
    '맛': ['맛', '요리', '음식', '메뉴', '향', '식감', '맛집', '고소', '달콤', '짭짤'],
    '가격': ['가격', '비싸', '저렴', '가성비', '비용', '비교', '비율', '가격대', '할인', '구성'],
    '서비스': ['서비스', '직원', '응대', '친절', '매너', '대응', '접대', '환대', '서빙', '응대'],
    '분위기': ['분위기', '환경', '인테리어', '공간', '장식', '조명', '음악', '분위기', '장소', '배경']
}

def categorize_review(review):
    tfidf_vectorizer = TfidfVectorizer()
    keyword_docs = [" ".join(keywords) for keywords in category_keywords.values()]
    tfidf_matrix = tfidf_vectorizer.fit_transform(keyword_docs + [review])
    cosine_similarities = cosine_similarity(tfidf_matrix[-1], tfidf_matrix[:-1]).flatten()
    top_categories = [categories[i] for i in cosine_similarities.argsort()[-2:]]
    return top_categories

# 대표 메뉴 추출
menu_keywords = ["피자", "스파게티", "버거", "스테이크", "초밥"]  # 예시 메뉴 키워드
menu_counter = Counter()
for review in preprocessed_data:
    for menu in menu_keywords:
        if menu in review:
            menu_counter[menu] += 1

top_menus = menu_counter.most_common(3)

# 감정 분석 모델 로드
tokenizer_kobert = BertTokenizer.from_pretrained('monologg/kobert')
model_kobert = BertForSequenceClassification.from_pretrained('monologg/kobert', num_labels=3).to(device)  # 3개의 레이블: 긍정, 부정, 중립

# 감정 분석 수행 및 카테고리별 비율 분석
sentiment_results = []
category_sentiments = {category: Counter() for category in categories}

for review in tqdm(preprocessed_data, desc="Processing Reviews"):
    inputs_kobert = tokenizer_kobert(review, return_tensors='pt', padding=True, truncation=True, max_length=128).to(device)
    with torch.no_grad():
        output_kobert = model_kobert(**inputs_kobert)
        sentiment = torch.argmax(output_kobert.logits, dim=1).item()

    categories_found = categorize_review(review)
    sentiment_results.append(sentiment)
    for category in categories_found:
        category_sentiments[category][sentiment] += 1

# 감정 분석 결과 시각화
sentiment_labels = ['Negative', 'Neutral', 'Positive']
sns.countplot(x=[sentiment_labels[s] for s in sentiment_results])
plt.title('Overall Sentiment Distribution')
plt.savefig('sentiment_distribution.png')
plt.show()

# 카테고리별 긍정/부정 비율 시각화
for category, sentiments in category_sentiments.items():
    sentiment_dist = [sentiments[i] for i in range(3)]
    plt.figure()
    sns.barplot(x=sentiment_labels, y=sentiment_dist)
    plt.title(f'Sentiment Distribution in Category: {category}')
    plt.savefig(f'{category}_sentiment_distribution.png')
    plt.show()

# 리뷰 요약 모델 로드 및 요약 생성 (간결한 요약 설정)
bart_tokenizer = PreTrainedTokenizerFast.from_pretrained('EbanLee/kobart-summary-v3')
bart_model = BartForConditionalGeneration.from_pretrained('EbanLee/kobart-summary-v3').to(device)

def summarize_reviews(reviews):
    combined_reviews = " ".join(reviews)
    inputs_bart = bart_tokenizer([combined_reviews], return_tensors='pt', padding=True, truncation=True, max_length=512).to(device)
    summary_ids = bart_model.generate(
        inputs_bart['input_ids'], 
        attention_mask=inputs_bart['attention_mask'], 
        max_length=50,  # 더 짧은 요약
        min_length=20,  
        length_penalty=2.0,  
        num_beams=4, 
        no_repeat_ngram_size=2,  
        repetition_penalty=1.2,  
        early_stopping=True
    )
    summary = bart_tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# 가게별 리뷰 종합 요약 및 점수 계산
store_summaries = {}
store_sentiments = {}
store_grouped = df.groupby('store_name')['content']

# 순차적으로 가게별 리뷰를 요약 생성 및 점수 계산
for store_name, reviews in tqdm(store_grouped, desc="Processing Stores"):
    try:
        preprocessed_reviews = [preprocess_text(review) for review in reviews]
        store_summaries[store_name] = summarize_reviews(preprocessed_reviews)

        # 감성 비율 계산
        sentiments = [sentiment_results[i] for i, r in enumerate(preprocessed_data) if r in reviews]
        sentiment_counts = Counter(sentiments)
        total_reviews = len(sentiments)
        sentiment_ratios = {label: sentiment_counts.get(i, 0) / total_reviews for i, label in enumerate(sentiment_labels)}

        # 카테고리별 점수 계산
        category_scores = {}
        for category in categories:
            category_count = sum(category_sentiments[category].values())
            category_scores[category] = category_sentiments[category][2] / category_count if category_count > 0 else 0  # 긍정 점수
        
        store_sentiments[store_name] = {
            'Sentiment Ratios': sentiment_ratios,
            'Category Scores': category_scores
        }

    except Exception as e:
        print(f"Error processing store {store_name}: {e}")

# 현재 날짜와 시간을 가져와서 파일 이름에 포함
current_time = datetime.now().strftime('%Y%m%d_%H%M%S')
file_name = f'{current_time}_store_review_summaries.csv'

# 결과를 CSV 파일로 저장
final_results = pd.DataFrame.from_dict(store_summaries, orient='index', columns=['Summary'])
final_results.to_csv(file_name)

sentiment_file_name = f'{current_time}_store_sentiments.csv'
sentiment_results_df = pd.DataFrame.from_dict(store_sentiments, orient='index')
sentiment_results_df.to_csv(sentiment_file_name)

print(f"Results saved to {file_name} and {sentiment_file_name}")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'KoBertTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# C:\Users\G-01\AppData\Roaming\Python\Python38\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at monologg/kobert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Processing Reviews: 100%|██████████| 53319/53319 [35:00<00:00, 25.38it/s]
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 47579 (\N{HANGUL SYLLABLE MAS}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47579 (\N{HANGUL SYLLABLE MAS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# C:\Users\G-01\AppData\Local\Temp\ipykernel_21268\4080117134.py:96: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(f'{category}_sentiment_distribution.png')
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\dl-dev\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Processing Stores:   0%|          | 1/737 [00:01<14:53,  1.21s/it]
# Error processing store (주)애브릿지: division by zero
# Processing Stores:   0%|          | 2/737 [00:02<14:05,  1.15s/it]
# Error processing store (주)플레이버타운: division by zero
# Processing Stores:   0%|          | 3/737 [00:03<13:13,  1.08s/it]
# Error processing store 1010 아프리카 유나이티드레스토랑: division by zero
# Processing Stores:   1%|          | 4/737 [00:04<13:23,  1.10s/it]
# Error processing store 72420 미아사거리점: division by zero
# Processing Stores:   1%|          | 5/737 [00:05<13:25,  1.10s/it]
# Error processing store 72420노원: division by zero
# Processing Stores:   1%|          | 6/737 [00:06<13:29,  1.11s/it]
# Error processing store 753 베이글 비스트로: division by zero
# Processing Stores:   1%|          | 7/737 [00:07<13:31,  1.11s/it]
# Error processing store 936치킨: division by zero
# Processing Stores:   1%|          | 8/737 [00:08<13:33,  1.12s/it]
# Error processing store Bins PHO (베트남 쌀국수): division by zero
# Processing Stores:   1%|          | 9/737 [00:10<13:33,  1.12s/it]
# Error processing store Bua thong: division by zero
# Processing Stores:   1%|▏         | 10/737 [00:11<13:36,  1.12s/it]
# Error processing store COCINA ESPANA(꼬시나 에스파냐): division by zero
# Processing Stores:   1%|▏         | 11/737 [00:11<12:11,  1.01s/it]
# Error processing store DRAFT 128: division by zero
# Processing Stores:   2%|▏         | 12/737 [00:13<12:36,  1.04s/it]
# Error processing store M키친(엠키친): division by zero
# Processing Stores:   2%|▏         | 13/737 [00:14<12:50,  1.06s/it]
# Error processing store SAFFRON RESTAURANT(사프란): division by zero
# Processing Stores:   2%|▏         | 14/737 [00:15<12:58,  1.08s/it]
# Error processing store TACO BITE(타코바이트): division by zero
# Processing Stores:   2%|▏         | 15/737 [00:16<12:37,  1.05s/it]
# Error processing store Tacobueno(타코부에노): division by zero
# Processing Stores:   2%|▏         | 16/737 [00:17<12:50,  1.07s/it]
# Error processing store Tom Thai ? 타이: division by zero
# Processing Stores:   2%|▏         | 17/737 [00:18<12:58,  1.08s/it]
# Error processing store hedgehog(해지호그): division by zero
# Processing Stores:   2%|▏         | 18/737 [00:19<13:04,  1.09s/it]
# Error processing store ㈜코끼리베이글: division by zero
# Processing Stores:   3%|▎         | 19/737 [00:20<13:06,  1.10s/it]
# Error processing store 가빈 커피(GABEAN cafe): division by zero
# Processing Stores:   3%|▎         | 20/737 [00:21<13:11,  1.10s/it]
# Error processing store 감성타코 비스트로 대학로점: division by zero
# Processing Stores:   3%|▎         | 21/737 [00:22<12:47,  1.07s/it]
# Error processing store 감자아일랜드 롯데월드몰점: division by zero
# Processing Stores:   3%|▎         | 22/737 [00:23<12:55,  1.09s/it]
# Error processing store 갓잇 강남점(GODEAT): division by zero
# Processing Stores:   3%|▎         | 23/737 [00:25<13:01,  1.09s/it]
# Error processing store 갓잇문래점(GODEAT): division by zero
# Processing Stores:   3%|▎         | 24/737 [00:26<13:11,  1.11s/it]
# Error processing store 강남 쌀국수 문정점: division by zero
# Processing Stores:   3%|▎         | 25/737 [00:27<12:46,  1.08s/it]
# Error processing store 강남쌀국수 마곡점: division by zero
# Processing Stores:   4%|▎         | 26/737 [00:28<12:57,  1.09s/it]
# Error processing store 강동호치민: division by zero
# Processing Stores:   4%|▎         | 27/737 [00:29<13:02,  1.10s/it]
# Error processing store 게르하우스 몽골식당: division by zero
# Processing Stores:   4%|▍         | 28/737 [00:30<12:36,  1.07s/it]
# Error processing store 경리단소셜클럽: division by zero
# Processing Stores:   4%|▍         | 29/737 [00:31<12:13,  1.04s/it]
# Error processing store 고렝: division by zero
# Processing Stores:   4%|▍         | 30/737 [00:32<12:32,  1.06s/it]
# Error processing store 고수타코(GOSUTACO)여의도KBS점: division by zero
# Processing Stores:   4%|▍         | 31/737 [00:33<12:43,  1.08s/it]
# Error processing store 고수한잎: division by zero
# Processing Stores:   4%|▍         | 32/737 [00:34<12:48,  1.09s/it]
# Error processing store 고스트블랙 연남점: division by zero
# Processing Stores:   4%|▍         | 33/737 [00:35<11:20,  1.04it/s]
# Error processing store 고피자 동대문역사점: division by zero
# Processing Stores:   5%|▍         | 34/737 [00:36<11:58,  1.02s/it]
# Error processing store 골드케밥: division by zero
# Processing Stores:   5%|▍         | 35/737 [00:37<11:11,  1.05it/s]
# Error processing store 구찌오스테리아: division by zero
# Processing Stores:   5%|▍         | 36/737 [00:38<11:43,  1.00s/it]
# Error processing store 국민빵집: division by zero
# Processing Stores:   5%|▌         | 37/737 [00:39<12:09,  1.04s/it]
# Error processing store 굿니스클럽: division by zero
# Processing Stores:   5%|▌         | 38/737 [00:40<11:58,  1.03s/it]
# Error processing store 규돈향: division by zero
# Processing Stores:   5%|▌         | 39/737 [00:41<10:15,  1.13it/s]
# Error processing store 그랑비노: division by zero
# Processing Stores:   5%|▌         | 40/737 [00:42<11:07,  1.04it/s]
# Error processing store 그랑플라스드이태원: division by zero
# Processing Stores:   6%|▌         | 41/737 [00:43<11:38,  1.00s/it]
# Error processing store 그레베르: division by zero
# Processing Stores:   6%|▌         | 42/737 [00:44<12:01,  1.04s/it]
# Error processing store 까브 테라스: division by zero
# Processing Stores:   6%|▌         | 43/737 [00:45<12:16,  1.06s/it]
# Error processing store 까사벨라즈: division by zero
# Processing Stores:   6%|▌         | 44/737 [00:46<12:25,  1.08s/it]
# Error processing store 깐부치킨(서래점): division by zero
# Processing Stores:   6%|▌         | 45/737 [00:47<12:34,  1.09s/it]
# Error processing store 꼬들삼겹살: division by zero
# Processing Stores:   6%|▌         | 46/737 [00:48<11:48,  1.02s/it]
# Error processing store 꼬메도르16: division by zero
# Processing Stores:   6%|▋         | 47/737 [00:49<12:05,  1.05s/it]
# Error processing store 꾸아 대학로점: division by zero
# Processing Stores:   7%|▋         | 48/737 [00:50<12:18,  1.07s/it]
# Error processing store 꾸아 서울숲점: division by zero
# Processing Stores:   7%|▋         | 49/737 [00:52<12:26,  1.08s/it]
# Error processing store 꾸아 이대점: division by zero
# Processing Stores:   7%|▋         | 50/737 [00:53<12:33,  1.10s/it]
# Error processing store 끌레망꾸꾸(clement coucou): division by zero
# Processing Stores:   7%|▋         | 51/737 [00:54<12:36,  1.10s/it]
# Error processing store 끌림 이탈리아: division by zero
# Processing Stores:   7%|▋         | 52/737 [00:55<12:35,  1.10s/it]
# Error processing store 낀라오: division by zero
# Processing Stores:   7%|▋         | 53/737 [00:56<12:43,  1.12s/it]
# Error processing store 낀티엔: division by zero
# Processing Stores:   7%|▋         | 54/737 [00:57<10:39,  1.07it/s]
# Error processing store 나 불러떠: division by zero
# Processing Stores:   7%|▋         | 55/737 [00:58<11:17,  1.01it/s]
# Error processing store 나누리잡화점: division by zero
# Processing Stores:   8%|▊         | 56/737 [00:59<11:42,  1.03s/it]
# Error processing store 나래함박 연남: division by zero
# Processing Stores:   8%|▊         | 57/737 [01:00<11:56,  1.05s/it]
# Error processing store 나무솥밥경리단: division by zero
# Processing Stores:   8%|▊         | 58/737 [01:01<12:11,  1.08s/it]
# Error processing store 나성타코 홍대점: division by zero
# Processing Stores:   8%|▊         | 59/737 [01:02<12:19,  1.09s/it]
# Error processing store 나이쏘이 하비오점: division by zero
# Processing Stores:   8%|▊         | 60/737 [01:03<12:26,  1.10s/it]
# Error processing store 나항: division by zero
# Processing Stores:   8%|▊         | 61/737 [01:04<12:26,  1.10s/it]
# Error processing store 낙원타코 용산아이파크몰점: division by zero
# Processing Stores:   8%|▊         | 62/737 [01:05<12:05,  1.08s/it]
# Error processing store 남미 플랜트 랩: division by zero
# Processing Stores:   9%|▊         | 63/737 [01:07<12:11,  1.09s/it]
# Error processing store 내슈빌 스테이크 하우스: division by zero
# Processing Stores:   9%|▊         | 64/737 [01:08<12:19,  1.10s/it]
# Error processing store 노르디: division by zero
# Processing Stores:   9%|▉         | 65/737 [01:08<11:03,  1.01it/s]
# Error processing store 노멀브런치(Normal Brunch): division by zero
# Processing Stores:   9%|▉         | 66/737 [01:10<11:28,  1.03s/it]
# Error processing store 노스티모: division by zero
# Processing Stores:   9%|▉         | 67/737 [01:10<10:31,  1.06it/s]
# Error processing store 노야 현대백화점목동: division by zero
# Processing Stores:   9%|▉         | 68/737 [01:11<11:05,  1.01it/s]
# Error processing store 노작가의 아지트: division by zero
# Processing Stores:   9%|▉         | 69/737 [01:12<11:02,  1.01it/s]
# Error processing store 노틀던 라팰리스 청담: division by zero
# Processing Stores:   9%|▉         | 70/737 [01:14<11:28,  1.03s/it]
# Error processing store 놉스 서울역점: division by zero
# Processing Stores:  10%|▉         | 71/737 [01:14<11:13,  1.01s/it]
# Error processing store 농농: division by zero
# Processing Stores:  10%|▉         | 72/737 [01:15<11:06,  1.00s/it]
# Error processing store 누들아한타이: division by zero
# Processing Stores:  10%|▉         | 73/737 [01:17<11:27,  1.04s/it]
# Error processing store 누산타라쿠: division by zero
# Processing Stores:  10%|█         | 74/737 [01:18<11:42,  1.06s/it]
# Error processing store 능동타코집: division by zero
# Processing Stores:  10%|█         | 75/737 [01:19<11:55,  1.08s/it]
# Error processing store 니들누들 목동점: division by zero
# Processing Stores:  10%|█         | 76/737 [01:20<12:02,  1.09s/it]
# Error processing store 다올: division by zero
# Processing Stores:  10%|█         | 77/737 [01:21<12:05,  1.10s/it]
# Error processing store 다이스웍스: division by zero
# Processing Stores:  11%|█         | 78/737 [01:22<12:07,  1.10s/it]
# Error processing store 달리181 상도점: division by zero
# Processing Stores:  11%|█         | 79/737 [01:23<11:46,  1.07s/it]
# Error processing store 달콤 왕가 탕후루 마들역점: division by zero
# Processing Stores:  11%|█         | 80/737 [01:24<11:56,  1.09s/it]
# Error processing store 댐굳서울(DAMN GOOD SEOUL): division by zero
# Processing Stores:  11%|█         | 81/737 [01:25<11:59,  1.10s/it]
# Error processing store 더 스트레인저(The Stranger): division by zero
# Processing Stores:  11%|█         | 82/737 [01:27<12:12,  1.12s/it]
# Error processing store 더마샬라 디타워점: division by zero
# Processing Stores:  11%|█▏        | 83/737 [01:28<12:12,  1.12s/it]
# Error processing store 더버튼스: division by zero
# Processing Stores:  11%|█▏        | 84/737 [01:29<12:15,  1.13s/it]
# Error processing store 더펄 바이 그릴도하: division by zero
# Processing Stores:  12%|█▏        | 85/737 [01:30<12:14,  1.13s/it]
# Error processing store 더플레이스 광화문SFC점: division by zero
# Processing Stores:  12%|█▏        | 86/737 [01:31<12:10,  1.12s/it]
# Error processing store 델리카트슨 한남: division by zero
# Processing Stores:  12%|█▏        | 87/737 [01:32<12:08,  1.12s/it]
# Error processing store 델리커리 동대문디디피점: division by zero
# Processing Stores:  12%|█▏        | 88/737 [01:33<12:08,  1.12s/it]
# Error processing store 델리커리 성수낙낙점: division by zero
# Processing Stores:  12%|█▏        | 89/737 [01:34<12:07,  1.12s/it]
# Error processing store 델리커리 용산아이파크몰점: division by zero
# Processing Stores:  12%|█▏        | 90/737 [01:35<11:38,  1.08s/it]
# Error processing store 델리커리 을지로pj점: division by zero
# Processing Stores:  12%|█▏        | 91/737 [01:37<11:45,  1.09s/it]
# Error processing store 델리케밥(Deli kebab): division by zero
# Processing Stores:  12%|█▏        | 92/737 [01:38<11:49,  1.10s/it]
# Error processing store 뎁짜이 가락시장역점 DEP TRAI: division by zero
# Processing Stores:  13%|█▎        | 93/737 [01:39<11:47,  1.10s/it]
# Error processing store 도만다 신용산점: division by zero
# Processing Stores:  13%|█▎        | 94/737 [01:40<11:49,  1.10s/it]
# Error processing store 도미노피자 삼성점: division by zero
# Processing Stores:  13%|█▎        | 95/737 [01:41<11:48,  1.10s/it]
# Error processing store 도미노피자 위례점: division by zero
# Processing Stores:  13%|█▎        | 96/737 [01:42<11:31,  1.08s/it]
# Error processing store 도미노피자월계점: division by zero
# Processing Stores:  13%|█▎        | 97/737 [01:43<11:37,  1.09s/it]
# Error processing store 도스타코스 마포공덕점: division by zero
# Processing Stores:  13%|█▎        | 98/737 [01:44<11:41,  1.10s/it]
# Error processing store 도스타코스 청계산입구역점: division by zero
# Processing Stores:  13%|█▎        | 99/737 [01:45<11:45,  1.11s/it]
# Error processing store 도우대디(Dough Daddy): division by zero
# Processing Stores:  14%|█▎        | 100/737 [01:46<11:47,  1.11s/it]
# Error processing store 도이농: division by zero
# Processing Stores:  14%|█▎        | 101/737 [01:48<11:44,  1.11s/it]
# Error processing store 도이칠란드 박 정릉시장점: division by zero
# Processing Stores:  14%|█▍        | 102/737 [01:49<11:42,  1.11s/it]
# Error processing store 돈천동 식당: division by zero
# Processing Stores:  14%|█▍        | 103/737 [01:50<11:42,  1.11s/it]
# Error processing store 동남쌀국: division by zero
# Processing Stores:  14%|█▍        | 104/737 [01:51<11:42,  1.11s/it]
# Error processing store 동남옥탑: division by zero
# Processing Stores:  14%|█▍        | 105/737 [01:52<11:45,  1.12s/it]
# Error processing store 동묘마케트: division by zero
# Processing Stores:  14%|█▍        | 106/737 [01:53<11:43,  1.11s/it]
# Error processing store 두들피스: division by zero
# Processing Stores:  15%|█▍        | 107/737 [01:54<11:44,  1.12s/it]
# Error processing store 두비두바(DoobeDoBar): division by zero
# Processing Stores:  15%|█▍        | 108/737 [01:55<11:19,  1.08s/it]
# Error processing store 드래곤힐 프린트샵: division by zero
# Processing Stores:  15%|█▍        | 109/737 [01:56<10:54,  1.04s/it]
# Error processing store 드렁킨타이 목동점: division by zero
# Processing Stores:  15%|█▍        | 110/737 [01:57<11:11,  1.07s/it]
# Error processing store 드포레와인&비스트로: division by zero
# Processing Stores:  15%|█▌        | 111/737 [01:58<11:19,  1.09s/it]
# Error processing store 디막: division by zero
# Processing Stores:  15%|█▌        | 112/737 [02:00<11:22,  1.09s/it]
# Error processing store 디어키트리(Dear.Kitri): division by zero
# Processing Stores:  15%|█▌        | 113/737 [02:01<11:28,  1.10s/it]
# Error processing store 따께리아&또르띠예리아 파코: division by zero
# Processing Stores:  15%|█▌        | 114/737 [02:02<11:26,  1.10s/it]
# Error processing store 따올라이 상도점: division by zero
# Processing Stores:  16%|█▌        | 115/737 [02:03<11:27,  1.11s/it]
# Error processing store 또이바엠: division by zero
# Processing Stores:  16%|█▌        | 116/737 [02:04<11:27,  1.11s/it]
# Error processing store 똔리우: division by zero
# Processing Stores:  16%|█▌        | 117/737 [02:05<11:30,  1.11s/it]
# Error processing store 뚝방닭구이 신내점: division by zero
# Processing Stores:  16%|█▌        | 118/737 [02:06<11:05,  1.07s/it]
# Error processing store 띤띤: division by zero
# Processing Stores:  16%|█▌        | 119/737 [02:07<11:11,  1.09s/it]
# Error processing store 띤띤익스프레스 고속터미널점: division by zero
# Processing Stores:  16%|█▋        | 120/737 [02:08<11:16,  1.10s/it]
# Error processing store 라따뚜이인서울: division by zero
# Processing Stores:  16%|█▋        | 121/737 [02:09<10:54,  1.06s/it]
# Error processing store 라뜰리에 이은: division by zero
# Processing Stores:  17%|█▋        | 122/737 [02:10<11:03,  1.08s/it]
# Error processing store 라브리크: division by zero
# Processing Stores:  17%|█▋        | 123/737 [02:12<11:08,  1.09s/it]
# Error processing store 라사 서울: division by zero
# Processing Stores:  17%|█▋        | 124/737 [02:13<11:20,  1.11s/it]
# Error processing store 라오삐약: division by zero
# Processing Stores:  17%|█▋        | 125/737 [02:14<11:19,  1.11s/it]
# Error processing store 라쿵푸마라탕 금호점: division by zero
# Processing Stores:  17%|█▋        | 126/737 [02:15<10:54,  1.07s/it]
# Error processing store 라페리체: division by zero
# Processing Stores:  17%|█▋        | 127/737 [02:16<11:02,  1.09s/it]
# Error processing store 라플랑  La Pleine: division by zero
# Processing Stores:  17%|█▋        | 128/737 [02:17<11:09,  1.10s/it]
# Error processing store 라피자노스트라: division by zero
# Processing Stores:  18%|█▊        | 129/737 [02:18<11:09,  1.10s/it]
# Error processing store 라홍방마라탕하월곡점: division by zero
# Processing Stores:  18%|█▊        | 130/737 [02:19<11:14,  1.11s/it]
# Error processing store 라화방 마라탕: division by zero
# Processing Stores:  18%|█▊        | 131/737 [02:20<11:13,  1.11s/it]
# Error processing store 란짠타부리: division by zero
# Processing Stores:  18%|█▊        | 132/737 [02:21<10:47,  1.07s/it]
# Error processing store 러스틱 오스테리아: division by zero
# Processing Stores:  18%|█▊        | 133/737 [02:23<10:54,  1.08s/it]
# Error processing store 러이포: division by zero
# Processing Stores:  18%|█▊        | 134/737 [02:24<11:02,  1.10s/it]
# Error processing store 럭키서울: division by zero
# Processing Stores:  18%|█▊        | 135/737 [02:25<11:06,  1.11s/it]
# Error processing store 럭키인디아: division by zero
# Processing Stores:  18%|█▊        | 136/737 [02:26<11:24,  1.14s/it]
# Error processing store 레 부르주아: division by zero
# Processing Stores:  19%|█▊        | 137/737 [02:27<11:19,  1.13s/it]
# Error processing store 레몬그라스타이 낙성대점: division by zero
# Processing Stores:  19%|█▊        | 138/737 [02:28<10:57,  1.10s/it]
# Error processing store 레스토랑 라모라: division by zero
# Processing Stores:  19%|█▉        | 139/737 [02:29<11:01,  1.11s/it]
# Error processing store 레스토랑꼬로(RESTAURANT Coro): division by zero
# Processing Stores:  19%|█▉        | 140/737 [02:30<11:03,  1.11s/it]
# Error processing store 레에스티우: division by zero
# Processing Stores:  19%|█▉        | 141/737 [02:31<10:58,  1.11s/it]
# Error processing store 로꼬브리또 자양점: division by zero
# Processing Stores:  19%|█▉        | 142/737 [02:32<10:09,  1.02s/it]
# Error processing store 로리스피자 Lorris Pizza Factory: division by zero
# Processing Stores:  19%|█▉        | 143/737 [02:33<10:23,  1.05s/it]
# Error processing store 로스 보라초스: division by zero
# Processing Stores:  20%|█▉        | 144/737 [02:35<10:37,  1.07s/it]
# Error processing store 로찌마곡(LodgeMagok): division by zero
# Processing Stores:  20%|█▉        | 145/737 [02:36<10:44,  1.09s/it]
# Error processing store 롤링파스타 대학로점: division by zero
# Processing Stores:  20%|█▉        | 146/737 [02:37<10:45,  1.09s/it]
# Error processing store 롤링파스타 동대문두타몰점: division by zero
# Processing Stores:  20%|█▉        | 147/737 [02:38<10:53,  1.11s/it]
# Error processing store 롬타이 LOM THAI: division by zero
# Processing Stores:  20%|██        | 148/737 [02:39<10:57,  1.12s/it]
# Error processing store 롱씨암(Rongsiam): division by zero
# Processing Stores:  20%|██        | 149/737 [02:40<10:59,  1.12s/it]
# Error processing store 룡관 (NHAT LONG QUAN): division by zero
# Processing Stores:  20%|██        | 150/737 [02:41<10:37,  1.09s/it]
# Error processing store 룡빈관: division by zero
# Processing Stores:  20%|██        | 151/737 [02:42<10:40,  1.09s/it]
# Error processing store 루트(LUT): division by zero
# Processing Stores:  21%|██        | 152/737 [02:43<10:40,  1.09s/it]
# Error processing store 류타이쿠진: division by zero
# Processing Stores:  21%|██        | 153/737 [02:45<10:42,  1.10s/it]
# Error processing store 르번미태릉점: division by zero
# Processing Stores:  21%|██        | 154/737 [02:46<10:46,  1.11s/it]
# Error processing store 리나스 서대문점: division by zero
# Processing Stores:  21%|██        | 155/737 [02:47<10:22,  1.07s/it]
# Error processing store 리젠트스카이: division by zero
# Processing Stores:  21%|██        | 156/737 [02:48<10:29,  1.08s/it]
# Error processing store 리틀 파파포 경희궁점: division by zero
# Processing Stores:  21%|██▏       | 157/737 [02:49<10:33,  1.09s/it]
# Error processing store 리틀방콕 공덕경의선숲길점: division by zero
# Processing Stores:  21%|██▏       | 158/737 [02:50<10:34,  1.10s/it]
# Error processing store 리틀방콕 길음뉴타운점: division by zero
# Processing Stores:  22%|██▏       | 159/737 [02:51<09:36,  1.00it/s]
# Error processing store 리틀방콕 왕십리뉴타운점: division by zero
# Processing Stores:  22%|██▏       | 160/737 [02:52<09:55,  1.03s/it]
# Error processing store 리틀방콕쌍문점: division by zero
# Processing Stores:  22%|██▏       | 161/737 [02:53<10:07,  1.05s/it]
# Error processing store 리틀파파포 명동점: division by zero
# Processing Stores:  22%|██▏       | 162/737 [02:54<10:16,  1.07s/it]
# Error processing store 리틀하노이 공릉점: division by zero
# Processing Stores:  22%|██▏       | 163/737 [02:55<10:25,  1.09s/it]
# Error processing store 리틀하노이 신내점: division by zero
# Processing Stores:  22%|██▏       | 164/737 [02:56<09:02,  1.06it/s]
# Error processing store 리틀하노이문래점: division by zero
# Processing Stores:  22%|██▏       | 165/737 [02:57<09:30,  1.00it/s]
# Error processing store 릭십: division by zero
# Processing Stores:  23%|██▎       | 166/737 [02:58<09:24,  1.01it/s]
# Error processing store 릴리스이나살: division by zero
# Processing Stores:  23%|██▎       | 167/737 [02:59<09:47,  1.03s/it]
# Error processing store 마낀카오 (Makin Kao): division by zero
# Processing Stores:  23%|██▎       | 168/737 [03:00<09:59,  1.05s/it]
# Error processing store 마라에 꼬치다: division by zero
# Processing Stores:  23%|██▎       | 169/737 [03:01<10:06,  1.07s/it]
# Error processing store 마라영웅 금호점: division by zero
# Processing Stores:  23%|██▎       | 170/737 [03:02<10:12,  1.08s/it]
# Error processing store 마라케쉬 레스토랑: division by zero
# Processing Stores:  23%|██▎       | 171/737 [03:03<09:54,  1.05s/it]
# Error processing store 마라하오 관악점: division by zero
# Processing Stores:  23%|██▎       | 172/737 [03:04<10:02,  1.07s/it]
# Error processing store 마라홀릭마라탕 숙대점: division by zero
# Processing Stores:  23%|██▎       | 173/737 [03:06<10:07,  1.08s/it]
# Error processing store 마린커피 빅히트 사옥점: division by zero
# Processing Stores:  24%|██▎       | 174/737 [03:07<10:13,  1.09s/it]
# Error processing store 마스터비엣 마포점: division by zero
# Processing Stores:  24%|██▎       | 175/737 [03:08<09:56,  1.06s/it]
# Error processing store 마스터비엣 서울역점: division by zero
# Processing Stores:  24%|██▍       | 176/737 [03:09<09:20,  1.00it/s]
# Error processing store 마이클식당: division by zero
# Processing Stores:  24%|██▍       | 177/737 [03:10<09:42,  1.04s/it]
# Error processing store 마크사이공: division by zero
# Processing Stores:  24%|██▍       | 178/737 [03:11<09:53,  1.06s/it]
# Error processing store 마토미: division by zero
# Processing Stores:  24%|██▍       | 179/737 [03:12<10:00,  1.08s/it]
# Error processing store 마하나콘: division by zero
# Processing Stores:  24%|██▍       | 180/737 [03:13<10:05,  1.09s/it]
# Error processing store 마하차이 서울숲점: division by zero
# Processing Stores:  25%|██▍       | 181/737 [03:14<10:10,  1.10s/it]
# Error processing store 맘맘테이블 신용산점: division by zero
# Processing Stores:  25%|██▍       | 182/737 [03:15<10:10,  1.10s/it]
# Error processing store 맘모스타코: division by zero
# Processing Stores:  25%|██▍       | 183/737 [03:16<10:12,  1.11s/it]
# Error processing store 맛의 정원: division by zero
# Processing Stores:  25%|██▍       | 184/737 [03:17<10:13,  1.11s/it]
# Error processing store 맛있는 스페인(Espana deliciosa): division by zero
# Processing Stores:  25%|██▌       | 185/737 [03:18<09:26,  1.03s/it]
# Error processing store 망원동 칼짬뽕: division by zero
# Processing Stores:  25%|██▌       | 186/737 [03:19<08:42,  1.05it/s]
# Error processing store 매드피자 고려대점: division by zero
# Processing Stores:  25%|██▌       | 187/737 [03:20<09:08,  1.00it/s]
# Error processing store 먼치오케이 샐러드 클럽 성북점: division by zero
# Processing Stores:  26%|██▌       | 188/737 [03:21<09:29,  1.04s/it]
# Error processing store 메딕(Medik): division by zero
# Processing Stores:  26%|██▌       | 189/737 [03:22<09:39,  1.06s/it]
# Error processing store 메르신 케밥: division by zero
# Processing Stores:  26%|██▌       | 190/737 [03:24<09:51,  1.08s/it]
# Error processing store 메종앙티브: division by zero
# Processing Stores:  26%|██▌       | 191/737 [03:25<09:58,  1.10s/it]
# Error processing store 메콩타이 고덕역점: division by zero
# Processing Stores:  26%|██▌       | 192/737 [03:26<10:09,  1.12s/it]
# Error processing store 멕시칸 라이브 그릴 서울길음역점: division by zero
# Processing Stores:  26%|██▌       | 193/737 [03:27<09:44,  1.07s/it]
# Error processing store 멕시칸라이브그릴 노원점: division by zero
# Processing Stores:  26%|██▋       | 194/737 [03:28<09:49,  1.09s/it]
# Error processing store 멕시칸라이브그릴 송파점: division by zero
# Processing Stores:  26%|██▋       | 195/737 [03:29<09:55,  1.10s/it]
# Error processing store 멕시칼리: division by zero
# Processing Stores:  27%|██▋       | 196/737 [03:30<09:56,  1.10s/it]
# Error processing store 멕시코다이너: division by zero
# Processing Stores:  27%|██▋       | 197/737 [03:31<10:00,  1.11s/it]
# Error processing store 멕시코밥집: division by zero
# Processing Stores:  27%|██▋       | 198/737 [03:32<10:00,  1.11s/it]
# Error processing store 멘지 건대점: division by zero
# Processing Stores:  27%|██▋       | 199/737 [03:34<09:58,  1.11s/it]
# Error processing store 면서울: division by zero
# Processing Stores:  27%|██▋       | 200/737 [03:35<09:58,  1.11s/it]
# Error processing store 명성냉삼: division by zero
# Processing Stores:  27%|██▋       | 201/737 [03:36<09:25,  1.05s/it]
# Error processing store 모아쏭 콤마: division by zero
# Processing Stores:  27%|██▋       | 202/737 [03:36<08:07,  1.10it/s]
# Error processing store 몬스택 버거: division by zero
# Processing Stores:  28%|██▊       | 203/737 [03:37<07:50,  1.14it/s]
# Error processing store 몬스터 포 (양천,강서): division by zero
# Processing Stores:  28%|██▊       | 204/737 [03:38<08:07,  1.09it/s]
# Error processing store 몬스터포 강동점: division by zero
# Processing Stores:  28%|██▊       | 205/737 [03:39<07:50,  1.13it/s]
# Error processing store 몬스터포 강서점: division by zero
# Processing Stores:  28%|██▊       | 206/737 [03:40<08:26,  1.05it/s]
# Error processing store 몬스터포 마포점: division by zero
# Processing Stores:  28%|██▊       | 207/737 [03:41<07:57,  1.11it/s]
# Error processing store 몬스터포 성북: division by zero
# Processing Stores:  28%|██▊       | 208/737 [03:42<07:53,  1.12it/s]
# Error processing store 몬스터포 영등포구점: division by zero
# Processing Stores:  28%|██▊       | 209/737 [03:43<08:28,  1.04it/s]
# Error processing store 몬안베띠 반포원베일리점: division by zero
# Processing Stores:  28%|██▊       | 210/737 [03:44<08:53,  1.01s/it]
# Error processing store 무한대 성신여대점: division by zero
# Processing Stores:  29%|██▊       | 211/737 [03:45<09:06,  1.04s/it]
# Error processing store 뮬라타: division by zero
# Processing Stores:  29%|██▉       | 212/737 [03:46<09:03,  1.03s/it]
# Error processing store 미드나잇마켓: division by zero
# Processing Stores:  29%|██▉       | 213/737 [03:47<09:16,  1.06s/it]
# Error processing store 미드나잇포레스트: division by zero
# Processing Stores:  29%|██▉       | 214/737 [03:48<09:25,  1.08s/it]
# Error processing store 미드템포: division by zero
# Processing Stores:  29%|██▉       | 215/737 [03:49<09:32,  1.10s/it]
# Error processing store 미방마포점: division by zero
# Processing Stores:  29%|██▉       | 216/737 [03:50<09:24,  1.08s/it]
# Error processing store 미분당 가양역점: division by zero
# Processing Stores:  29%|██▉       | 217/737 [03:51<09:27,  1.09s/it]
# Error processing store 미분당 고척점: division by zero
# Processing Stores:  30%|██▉       | 218/737 [03:53<09:31,  1.10s/it]
# Error processing store 미분당 구로디지털단지점: division by zero
# Processing Stores:  30%|██▉       | 219/737 [03:54<09:34,  1.11s/it]
# Error processing store 미분당 마곡점: division by zero
# Processing Stores:  30%|██▉       | 220/737 [03:55<09:35,  1.11s/it]
# Error processing store 미분당 문래점: division by zero
# Processing Stores:  30%|██▉       | 221/737 [03:56<09:35,  1.12s/it]
# Error processing store 미분당 상암DMC점: division by zero
# Processing Stores:  30%|███       | 222/737 [03:57<09:17,  1.08s/it]
# Error processing store 미분당 양천구청점: division by zero
# Processing Stores:  30%|███       | 223/737 [03:58<09:21,  1.09s/it]
# Error processing store 미분당(약수점): division by zero
# Processing Stores:  30%|███       | 224/737 [03:59<09:27,  1.11s/it]
# Error processing store 미분당(잠실학원가점): division by zero
# Processing Stores:  31%|███       | 225/737 [04:00<09:27,  1.11s/it]
# Error processing store 미스사이공 고덕비즈밸리점: division by zero
# Processing Stores:  31%|███       | 226/737 [04:01<09:25,  1.11s/it]
# Error processing store 미스사이공 공릉점: division by zero
# Processing Stores:  31%|███       | 227/737 [04:03<09:23,  1.11s/it]
# Error processing store 미스사이공 불광점: division by zero
# Processing Stores:  31%|███       | 228/737 [04:03<09:02,  1.07s/it]
# Error processing store 미스사이공 상도역점: division by zero
# Processing Stores:  31%|███       | 229/737 [04:05<09:08,  1.08s/it]
# Error processing store 미스사이공 세종대점: division by zero
# Processing Stores:  31%|███       | 230/737 [04:06<09:12,  1.09s/it]
# Error processing store 미스사이공 신촌역점: division by zero
# Processing Stores:  31%|███▏      | 231/737 [04:07<09:19,  1.11s/it]
# Error processing store 미스사이공 역삼점: division by zero
# Processing Stores:  31%|███▏      | 232/737 [04:08<09:18,  1.11s/it]
# Error processing store 미스사이공 포이사거리점: division by zero
# Processing Stores:  32%|███▏      | 233/737 [04:09<09:16,  1.10s/it]
# Error processing store 미스사이공상암DMC점: division by zero
# Processing Stores:  32%|███▏      | 234/737 [04:10<09:19,  1.11s/it]
# Error processing store 미스사이공장안점: division by zero
# Processing Stores:  32%|███▏      | 235/737 [04:11<09:18,  1.11s/it]
# Error processing store 미스타쌀국수 자곡점: division by zero
# Processing Stores:  32%|███▏      | 236/737 [04:12<09:19,  1.12s/it]
# Error processing store 미앙: division by zero
# Processing Stores:  32%|███▏      | 237/737 [04:14<09:17,  1.11s/it]
# Error processing store 미우미가: division by zero
# Processing Stores:  32%|███▏      | 238/737 [04:15<09:17,  1.12s/it]
# Error processing store 미태리 수서역점: division by zero
# Processing Stores:  32%|███▏      | 239/737 [04:16<09:16,  1.12s/it]
# Error processing store 미트로칼(MEAT LOKAAL): division by zero
# Processing Stores:  33%|███▎      | 240/737 [04:17<09:14,  1.12s/it]
# Error processing store 밀객: division by zero
# Processing Stores:  33%|███▎      | 241/737 [04:18<08:51,  1.07s/it]
# Error processing store 바리 슈퍼푸드 광화문점: division by zero
# Processing Stores:  33%|███▎      | 242/737 [04:19<08:33,  1.04s/it]
# Error processing store 바리 시청점: division by zero
# Processing Stores:  33%|███▎      | 243/737 [04:20<08:43,  1.06s/it]
# Error processing store 바스버거후암점: division by zero
# Processing Stores:  33%|███▎      | 244/737 [04:21<08:51,  1.08s/it]
# Error processing store 바오공 베트남 쌀국수: division by zero
# Processing Stores:  33%|███▎      | 245/737 [04:22<08:05,  1.01it/s]
# Error processing store 바우네나주곰탕 까치산역점: division by zero
# Processing Stores:  33%|███▎      | 246/737 [04:23<08:11,  1.00s/it]
# Error processing store 바우슈텔러(BAUSTELLE): division by zero
# Processing Stores:  34%|███▎      | 247/737 [04:24<08:26,  1.03s/it]
# Error processing store 박호 Bac Ho: division by zero
# Processing Stores:  34%|███▎      | 248/737 [04:25<08:38,  1.06s/it]
# Error processing store 반둥식당: division by zero
# Processing Stores:  34%|███▍      | 249/737 [04:26<07:54,  1.03it/s]
# Error processing store 반미362 고대 안암점: division by zero
# Processing Stores:  34%|███▍      | 250/737 [04:27<08:14,  1.02s/it]
# Error processing store 반미띠: division by zero
# Processing Stores:  34%|███▍      | 251/737 [04:28<08:33,  1.06s/it]
# Error processing store 반수우안(VAN XUAN): division by zero
# Processing Stores:  34%|███▍      | 252/737 [04:29<08:39,  1.07s/it]
# Error processing store 반포식스 광화문점: division by zero
# Processing Stores:  34%|███▍      | 253/737 [04:30<08:46,  1.09s/it]
# Error processing store 반포식스 교대역점: division by zero
# Processing Stores:  34%|███▍      | 254/737 [04:31<08:47,  1.09s/it]
# Error processing store 반포식스 구로점: division by zero
# Processing Stores:  35%|███▍      | 255/737 [04:33<08:52,  1.10s/it]
# Error processing store 반포식스 딜리버리 교대역점: division by zero
# Processing Stores:  35%|███▍      | 256/737 [04:34<08:53,  1.11s/it]
# Error processing store 반포식스 선릉역점: division by zero
# Processing Stores:  35%|███▍      | 257/737 [04:35<08:54,  1.11s/it]
# Error processing store 반포식스 을지트윈타워점: division by zero
# Processing Stores:  35%|███▌      | 258/737 [04:36<07:50,  1.02it/s]
# Error processing store 반포식스 포스코사거리점: division by zero
# Processing Stores:  35%|███▌      | 259/737 [04:37<08:09,  1.02s/it]
# Error processing store 반피셋: division by zero
# Processing Stores:  35%|███▌      | 260/737 [04:37<07:34,  1.05it/s]
# Error processing store 반피쏭: division by zero
# Processing Stores:  35%|███▌      | 261/737 [04:39<07:58,  1.01s/it]
# Error processing store 발리다포차(한남점): division by zero
# Processing Stores:  36%|███▌      | 262/737 [04:40<08:11,  1.04s/it]
# Error processing store 발리문: division by zero
# Processing Stores:  36%|███▌      | 263/737 [04:41<08:22,  1.06s/it]
# Error processing store 발리인망원: division by zero
# Processing Stores:  36%|███▌      | 264/737 [04:42<08:30,  1.08s/it]
# Error processing store 방방(VINVIN): division by zero
# Processing Stores:  36%|███▌      | 265/737 [04:43<08:18,  1.06s/it]
# Error processing store 방콕상회: division by zero
# Processing Stores:  36%|███▌      | 266/737 [04:44<08:29,  1.08s/it]
# Error processing store 방콕언니: division by zero
# Processing Stores:  36%|███▌      | 267/737 [04:45<08:18,  1.06s/it]
# Error processing store 배달의 쌀국수 서초점: division by zero
# Processing Stores:  36%|███▋      | 268/737 [04:46<08:01,  1.03s/it]
# Error processing store 배달의쌀국수 사당방배점: division by zero
# Processing Stores:  36%|███▋      | 269/737 [04:47<07:50,  1.01s/it]
# Error processing store 배달의쌀국수건대점: division by zero
# Processing Stores:  37%|███▋      | 270/737 [04:47<06:31,  1.19it/s]
# Error processing store 배달한상: division by zero
# Processing Stores:  37%|███▋      | 271/737 [04:49<07:11,  1.08it/s]
# Error processing store 백스트리트독스(Backstreet Dogs): division by zero
# Processing Stores:  37%|███▋      | 272/737 [04:49<06:37,  1.17it/s]
# Error processing store 버거앤타코 홈플러스강서점: division by zero
# Processing Stores:  37%|███▋      | 273/737 [04:50<07:12,  1.07it/s]
# Error processing store 버거주의: division by zero
# Processing Stores:  37%|███▋      | 274/737 [04:51<07:20,  1.05it/s]
# Error processing store 버거플리즈: division by zero
# Processing Stores:  37%|███▋      | 275/737 [04:52<07:46,  1.01s/it]
# Error processing store 버팔로스팟(Buffalo Spot): division by zero
# Processing Stores:  37%|███▋      | 276/737 [04:53<06:52,  1.12it/s]
# Error processing store 베르도네(Verdone) 신당: division by zero
# Processing Stores:  38%|███▊      | 277/737 [04:54<07:21,  1.04it/s]
# Error processing store 베베르카: division by zero
# Processing Stores:  38%|███▊      | 278/737 [04:55<06:51,  1.12it/s]
# Error processing store 베어스타코 건대점: division by zero
# Processing Stores:  38%|███▊      | 279/737 [04:56<07:20,  1.04it/s]
# Error processing store 베어스타코 마곡점: division by zero
# Processing Stores:  38%|███▊      | 280/737 [04:57<07:40,  1.01s/it]
# Error processing store 베어스타코 본점: division by zero
# Processing Stores:  38%|███▊      | 281/737 [04:58<07:33,  1.00it/s]
# Error processing store 베어스타코 아현공덕점: division by zero
# Processing Stores:  38%|███▊      | 282/737 [04:59<07:49,  1.03s/it]
# Error processing store 베이비펌킨(babypumpkin): division by zero
# Processing Stores:  38%|███▊      | 283/737 [05:00<08:03,  1.06s/it]
# Error processing store 베이커리 토드: division by zero
# Processing Stores:  39%|███▊      | 284/737 [05:01<08:03,  1.07s/it]
# Error processing store 베이코닉브런치바(갤러리아압구정): division by zero
# Processing Stores:  39%|███▊      | 285/737 [05:03<08:10,  1.09s/it]
# Error processing store 베카 프리미엄 델리샵: division by zero
# Processing Stores:  39%|███▉      | 286/737 [05:04<07:51,  1.05s/it]
# Error processing store 베트남 골목식당 청계산입구역점: division by zero
# Processing Stores:  39%|███▉      | 287/737 [05:05<07:57,  1.06s/it]
# Error processing store 베트남노상식당목동점: division by zero
# Processing Stores:  39%|███▉      | 288/737 [05:06<08:04,  1.08s/it]
# Error processing store 베트남돼지: division by zero
# Processing Stores:  39%|███▉      | 289/737 [05:07<08:11,  1.10s/it]
# Error processing store 벤탄빌라(목동파리공원점): division by zero
# Processing Stores:  39%|███▉      | 290/737 [05:08<08:15,  1.11s/it]
# Error processing store 벨라또띠아: division by zero
# Processing Stores:  39%|███▉      | 291/737 [05:09<08:14,  1.11s/it]
# Error processing store 벱비엣을지로본점: division by zero
# Processing Stores:  40%|███▉      | 292/737 [05:10<08:14,  1.11s/it]
# Error processing store 보니스피자 용산(Bonny's Pizza): division by zero
# Processing Stores:  40%|███▉      | 293/737 [05:11<07:55,  1.07s/it]
# Error processing store 보문745: division by zero
# Processing Stores:  40%|███▉      | 294/737 [05:12<07:43,  1.05s/it]
# Error processing store 보스버거(Boss Burger): division by zero
# Processing Stores:  40%|████      | 295/737 [05:13<07:55,  1.08s/it]
# Error processing store 부두비스트로테크: division by zero
# Processing Stores:  40%|████      | 296/737 [05:15<07:59,  1.09s/it]
# Error processing store 부리나케밥: division by zero
# Processing Stores:  40%|████      | 297/737 [05:16<08:03,  1.10s/it]
# Error processing store 부리또인자양점: division by zero
# Processing Stores:  40%|████      | 298/737 [05:17<07:56,  1.09s/it]
# Error processing store 분타 일원점: division by zero
# Processing Stores:  41%|████      | 299/737 [05:18<07:58,  1.09s/it]
# Error processing store 브라이틀링 키친: division by zero
# Processing Stores:  41%|████      | 300/737 [05:19<08:00,  1.10s/it]
# Error processing store 브로트아트 쿠셰: division by zero
# Processing Stores:  41%|████      | 301/737 [05:20<08:01,  1.10s/it]
# Error processing store 블루누드: division by zero
# Processing Stores:  41%|████      | 302/737 [05:21<08:03,  1.11s/it]
# Error processing store 비421: division by zero
# Processing Stores:  41%|████      | 303/737 [05:22<08:03,  1.12s/it]
# Error processing store 비노 보스코(Vino Bosco): division by zero
# Processing Stores:  41%|████      | 304/737 [05:23<07:29,  1.04s/it]
# Error processing store 비스트로 멕시: division by zero
# Processing Stores:  41%|████▏     | 305/737 [05:24<07:39,  1.06s/it]
# Error processing store 비스트로 한강: division by zero
# Processing Stores:  42%|████▏     | 306/737 [05:25<07:45,  1.08s/it]
# Error processing store 비스트로류: division by zero
# Processing Stores:  42%|████▏     | 307/737 [05:27<07:54,  1.10s/it]
# Error processing store 비스트로베름: division by zero
# Processing Stores:  42%|████▏     | 308/737 [05:27<07:22,  1.03s/it]
# Error processing store 비스트로에버: division by zero
# Processing Stores:  42%|████▏     | 309/737 [05:29<07:33,  1.06s/it]
# Error processing store 비스트로피자 공덕점: division by zero
# Processing Stores:  42%|████▏     | 310/737 [05:30<07:38,  1.07s/it]
# Error processing store 비아세라(Via sera): division by zero
# Processing Stores:  42%|████▏     | 311/737 [05:31<07:19,  1.03s/it]
# Error processing store 비엣하노이(VIET HANOI): division by zero
# Processing Stores:  42%|████▏     | 312/737 [05:32<07:30,  1.06s/it]
# Error processing store 비욘드비엣남 국회의사당점: division by zero
# Processing Stores:  42%|████▏     | 313/737 [05:33<07:28,  1.06s/it]
# Error processing store 비욘드비엣남 선릉점: division by zero
# Processing Stores:  43%|████▎     | 314/737 [05:34<07:34,  1.08s/it]
# Error processing store 빌라커피(Villa Coffe): division by zero
# Processing Stores:  43%|████▎     | 315/737 [05:35<07:40,  1.09s/it]
# Error processing store 쁘라텟타이: division by zero
# Processing Stores:  43%|████▎     | 316/737 [05:36<07:42,  1.10s/it]
# Error processing store 사계원: division by zero
# Processing Stores:  43%|████▎     | 317/737 [05:37<07:44,  1.11s/it]
# Error processing store 사보리(SABORI): division by zero
# Processing Stores:  43%|████▎     | 318/737 [05:38<07:43,  1.11s/it]
# Error processing store 사이공 본가 개봉역점: division by zero
# Processing Stores:  43%|████▎     | 319/737 [05:39<07:42,  1.11s/it]
# Error processing store 사이공본가 강일점: division by zero
# Processing Stores:  43%|████▎     | 320/737 [05:40<06:43,  1.03it/s]
# Error processing store 사이공본가 교대점: division by zero
# Processing Stores:  44%|████▎     | 321/737 [05:41<07:07,  1.03s/it]
# Error processing store 사이공본가 동대문역사점: division by zero
# Processing Stores:  44%|████▎     | 322/737 [05:42<07:17,  1.06s/it]
# Error processing store 사이공본가 암사점: division by zero
# Processing Stores:  44%|████▍     | 323/737 [05:43<07:09,  1.04s/it]
# Error processing store 사이공본가 정릉점: division by zero
# Processing Stores:  44%|████▍     | 324/737 [05:44<06:59,  1.02s/it]
# Error processing store 사이공본가(혜화점): division by zero
# Processing Stores:  44%|████▍     | 325/737 [05:45<07:10,  1.05s/it]
# Error processing store 사이공파크(SAIGON PARK): division by zero
# Processing Stores:  44%|████▍     | 326/737 [05:46<06:18,  1.09it/s]
# Error processing store 산쪼메 방배직영점: division by zero
# Processing Stores:  44%|████▍     | 327/737 [05:47<06:39,  1.03it/s]
# Error processing store 살라댕앰버시: division by zero
# Processing Stores:  45%|████▍     | 328/737 [05:48<06:14,  1.09it/s]
# Error processing store 살롱 드 이자드(Salon de Izzard): division by zero
# Processing Stores:  45%|████▍     | 329/737 [05:49<06:39,  1.02it/s]
# Error processing store 삼미 양꼬치: division by zero
# Processing Stores:  45%|████▍     | 330/737 [05:50<06:54,  1.02s/it]
# Error processing store 샐러드로우앤트라타굽은다리역점: division by zero
# Processing Stores:  45%|████▍     | 331/737 [05:51<07:04,  1.05s/it]
# Error processing store 생어거스틴 김포공항점: division by zero
# Processing Stores:  45%|████▌     | 332/737 [05:52<07:12,  1.07s/it]
# Error processing store 생어거스틴 마곡점: division by zero
# Processing Stores:  45%|████▌     | 333/737 [05:54<07:18,  1.09s/it]
# Error processing store 생활맥주 대학로 좁은골목점: division by zero
# Processing Stores:  45%|████▌     | 334/737 [05:55<07:19,  1.09s/it]
# Error processing store 생활맥주 삼성코엑스2호점: division by zero
# Processing Stores:  45%|████▌     | 335/737 [05:56<07:21,  1.10s/it]
# Error processing store 샤오당쟈(가산점): division by zero
# Processing Stores:  46%|████▌     | 336/737 [05:57<07:20,  1.10s/it]
# Error processing store 서오릉피자 공릉점: division by zero
# Processing Stores:  46%|████▌     | 337/737 [05:58<07:23,  1.11s/it]
# Error processing store 서오릉피자 서교점: division by zero
# Processing Stores:  46%|████▌     | 338/737 [05:59<07:24,  1.11s/it]
# Error processing store 서울 파스타 일만치노: division by zero
# Processing Stores:  46%|████▌     | 339/737 [06:00<07:22,  1.11s/it]
# Error processing store 성수명당: division by zero
# Processing Stores:  46%|████▌     | 340/737 [06:01<07:22,  1.11s/it]
# Error processing store 세이치즈(Say Cheese) 거여점: division by zero
# Processing Stores:  46%|████▋     | 341/737 [06:02<07:20,  1.11s/it]
# Error processing store 센터바: division by zero
# Processing Stores:  46%|████▋     | 342/737 [06:04<07:21,  1.12s/it]
# Error processing store 소랑면: division by zero
# Processing Stores:  47%|████▋     | 343/737 [06:05<07:17,  1.11s/it]
# Error processing store 소셜해이븐: division by zero
# Processing Stores:  47%|████▋     | 344/737 [06:06<07:16,  1.11s/it]
# Error processing store 소이54: division by zero
# Processing Stores:  47%|████▋     | 345/737 [06:07<07:15,  1.11s/it]
# Error processing store 소이연남 목동SBS점: division by zero
# Processing Stores:  47%|████▋     | 346/737 [06:08<07:16,  1.12s/it]
# Error processing store 소이연남 브라이튼여의도점: division by zero
# Processing Stores:  47%|████▋     | 347/737 [06:09<07:15,  1.12s/it]
# Error processing store 소이연남 신세계백화점 본점: division by zero
# Processing Stores:  47%|████▋     | 348/737 [06:10<07:18,  1.13s/it]
# Error processing store 소이연남 파미에스테이션점: division by zero
# Processing Stores:  47%|████▋     | 349/737 [06:11<07:00,  1.09s/it]
# Error processing store 솔빈덕: division by zero
# Processing Stores:  47%|████▋     | 350/737 [06:12<07:04,  1.10s/it]
# Error processing store 솔솥 마곡점: division by zero
# Processing Stores:  48%|████▊     | 351/737 [06:14<07:03,  1.10s/it]
# Error processing store 솔솥노원: division by zero
# Processing Stores:  48%|████▊     | 352/737 [06:15<07:04,  1.10s/it]
# Error processing store 쇼쿠지 양재점: division by zero
# Processing Stores:  48%|████▊     | 353/737 [06:16<06:48,  1.06s/it]
# Error processing store 쉐 올리비아: division by zero
# Processing Stores:  48%|████▊     | 354/737 [06:16<06:19,  1.01it/s]
# Error processing store 슈가스컬 센트럴시티점: division by zero
# Processing Stores:  48%|████▊     | 355/737 [06:18<06:31,  1.03s/it]
# Error processing store 스미카츠 압구정본점: division by zero
# Processing Stores:  48%|████▊     | 356/737 [06:18<05:54,  1.07it/s]
# Error processing store 스시이안앤 강남역점: division by zero
# Processing Stores:  48%|████▊     | 357/737 [06:19<06:14,  1.01it/s]
# Error processing store 스와가트(은평뉴타운점): division by zero
# Processing Stores:  49%|████▊     | 358/737 [06:20<06:27,  1.02s/it]
# Error processing store 스위티시카빙: division by zero
# Processing Stores:  49%|████▊     | 359/737 [06:22<06:36,  1.05s/it]
# Error processing store 스트릿 파르나스몰점: division by zero
# Processing Stores:  49%|████▉     | 360/737 [06:22<06:07,  1.03it/s]
# ...
# Processing Stores:  82%|████████▏ | 606/737 [10:44<02:23,  1.10s/it]
# Error processing store 팅키 케이크(TINKY CAKE): division by zero
# Processing Stores:  82%|████████▏ | 607/737 [10:45<02:18,  1.07s/it]
# Error processing store 파스타입니다 성북구청점: division by zero
# Processing Stores:  82%|████████▏ | 608/737 [10:46<02:16,  1.06s/it]
# Error processing store 파스타입니다(왕십리점): division by zero
# Processing Stores:  83%|████████▎ | 609/737 [10:47<02:17,  1.08s/it]
# Error processing store 파이브가이즈 서울역: division by zero
# Processing Stores:  83%|████████▎ | 610/737 [10:48<02:18,  1.09s/it]
# Error processing store 파파야리프 코엑스점: division by zero
# Processing Stores:  83%|████████▎ | 611/737 [10:49<02:18,  1.10s/it]
# Error processing store 파파이스 광화문점: division by zero
# Processing Stores:  83%|████████▎ | 612/737 [10:50<02:18,  1.11s/it]
# Error processing store 파파호(공덕): division by zero
# Processing Stores:  83%|████████▎ | 613/737 [10:52<02:18,  1.11s/it]
# Error processing store 팟카파우: division by zero
# Processing Stores:  83%|████████▎ | 614/737 [10:53<02:17,  1.12s/it]
# Error processing store 팟타이 로얄(Pad Thai Royal): division by zero
# Processing Stores:  83%|████████▎ | 615/737 [10:54<02:16,  1.12s/it]
# Error processing store 퍼부어 건대점: division by zero
# Processing Stores:  84%|████████▎ | 616/737 [10:55<02:04,  1.03s/it]
# Error processing store 퍼부어 서울숲점: division by zero
# Processing Stores:  84%|████████▎ | 617/737 [10:56<02:02,  1.02s/it]
# Error processing store 퍼부어 여의도점: division by zero
# Processing Stores:  84%|████████▍ | 618/737 [10:56<01:51,  1.06it/s]
# Error processing store 퍼틴 NC백화점 구로점: division by zero
# Processing Stores:  84%|████████▍ | 619/737 [10:57<01:57,  1.01it/s]
# Error processing store 퍼틴 롯데캐슬점: division by zero
# Processing Stores:  84%|████████▍ | 620/737 [10:59<02:00,  1.03s/it]
# Error processing store 퍼틴 여의도: division by zero
# Processing Stores:  84%|████████▍ | 621/737 [11:00<02:02,  1.06s/it]
# Error processing store 페르바코(PERBACCO): division by zero
# Processing Stores:  84%|████████▍ | 622/737 [11:01<02:03,  1.07s/it]
# Error processing store 페이퍼앤조모(Paper and jomo): division by zero
# Processing Stores:  85%|████████▍ | 623/737 [11:02<01:59,  1.05s/it]
# Error processing store 페이페이 신세계 타임스퀘어점: division by zero
# Processing Stores:  85%|████████▍ | 624/737 [11:03<02:00,  1.07s/it]
# Error processing store 펠리스 산쵸 서초점: division by zero
# Processing Stores:  85%|████████▍ | 625/737 [11:04<02:01,  1.08s/it]
# Error processing store 포 시애틀 가든파이브점: division by zero
# Processing Stores:  85%|████████▍ | 626/737 [11:05<01:56,  1.05s/it]
# Error processing store 포36거리 낙성대역점: division by zero
# Processing Stores:  85%|████████▌ | 627/737 [11:06<01:57,  1.07s/it]
# Error processing store 포490베트남쌀국수: division by zero
# Processing Stores:  85%|████████▌ | 628/737 [11:07<01:58,  1.09s/it]
# Error processing store 포고(phogo): division by zero
# Processing Stores:  85%|████████▌ | 629/737 [11:08<01:57,  1.09s/it]
# Error processing store 포맨스: division by zero
# Processing Stores:  85%|████████▌ | 630/737 [11:09<01:57,  1.10s/it]
# Error processing store 포메인 RED 남대문점: division by zero
# Processing Stores:  86%|████████▌ | 631/737 [11:11<01:57,  1.11s/it]
# Error processing store 포메인 마곡나루점: division by zero
# Processing Stores:  86%|████████▌ | 632/737 [11:12<01:56,  1.11s/it]
# Error processing store 포메인 암사역점: division by zero
# Processing Stores:  86%|████████▌ | 633/737 [11:13<01:55,  1.11s/it]
# Error processing store 포메인 황학롯데캐슬점: division by zero
# Processing Stores:  86%|████████▌ | 634/737 [11:14<01:54,  1.12s/it]
# Error processing store 포몬스 베트남쌀국수(방배점): division by zero
# Processing Stores:  86%|████████▌ | 635/737 [11:15<01:53,  1.11s/it]
# Error processing store 포몬스 양재점: division by zero
# Processing Stores:  86%|████████▋ | 636/737 [11:16<01:52,  1.11s/it]
# Error processing store 포몬스 잠실점 (Phomons): division by zero
# Processing Stores:  86%|████████▋ | 637/737 [11:17<01:51,  1.12s/it]
# Error processing store 포미래: division by zero
# Processing Stores:  87%|████████▋ | 638/737 [11:18<01:50,  1.12s/it]
# Error processing store 포베이 동대문종합시장점: division by zero
# Processing Stores:  87%|████████▋ | 639/737 [11:20<01:49,  1.11s/it]
# Error processing store 포베이강변테크노마트점: division by zero
# Processing Stores:  87%|████████▋ | 640/737 [11:21<01:48,  1.11s/it]
# Error processing store 포브라더스 종로점: division by zero
# Processing Stores:  87%|████████▋ | 641/737 [11:22<01:45,  1.10s/it]
# Error processing store 포시애틀 헬리오시티점: division by zero
# Processing Stores:  87%|████████▋ | 642/737 [11:23<01:45,  1.11s/it]
# Error processing store 포싸이: division by zero
# Processing Stores:  87%|████████▋ | 643/737 [11:24<01:44,  1.11s/it]
# Error processing store 포아잉트: division by zero
# Processing Stores:  87%|████████▋ | 644/737 [11:25<01:40,  1.08s/it]
# Error processing store 포안나: division by zero
# Processing Stores:  88%|████████▊ | 645/737 [11:26<01:41,  1.11s/it]
# Error processing store 포앤반하계역점: division by zero
# Processing Stores:  88%|████████▊ | 646/737 [11:27<01:41,  1.11s/it]
# Error processing store 포앤시드니 신내 SK V1 센터점: division by zero
# Processing Stores:  88%|████████▊ | 647/737 [11:28<01:40,  1.12s/it]
# Error processing store 포앤시드니중계점: division by zero
# Processing Stores:  88%|████████▊ | 648/737 [11:30<01:40,  1.13s/it]
# Error processing store 포언 시청점: division by zero
# Processing Stores:  88%|████████▊ | 649/737 [11:31<01:38,  1.12s/it]
# Error processing store 포에버얌 발산점: division by zero
# Processing Stores:  88%|████████▊ | 650/737 [11:32<01:37,  1.12s/it]
# Error processing store 포옹남 목동: division by zero
# Processing Stores:  88%|████████▊ | 651/737 [11:33<01:36,  1.12s/it]
# Error processing store 포옹남 서대문: division by zero
# Processing Stores:  88%|████████▊ | 652/737 [11:34<01:35,  1.12s/it]
# Error processing store 포옹남 하월곡: division by zero
# Processing Stores:  89%|████████▊ | 653/737 [11:35<01:30,  1.08s/it]
# Error processing store 포이스트 서울양평점: division by zero
# Processing Stores:  89%|████████▊ | 654/737 [11:36<01:31,  1.10s/it]
# Error processing store 포자딘: division by zero
# Processing Stores:  89%|████████▉ | 655/737 [11:37<01:30,  1.11s/it]
# Error processing store 포짜오: division by zero
# Processing Stores:  89%|████████▉ | 656/737 [11:38<01:29,  1.11s/it]
# Error processing store 포케박스 해방촌점: division by zero
# Processing Stores:  89%|████████▉ | 657/737 [11:40<01:29,  1.12s/it]
# Error processing store 포케올데이 삼성점: division by zero
# Processing Stores:  89%|████████▉ | 658/737 [11:40<01:19,  1.00s/it]
# Error processing store 포케올데이 성북구청점: division by zero
# Processing Stores:  89%|████████▉ | 659/737 [11:41<01:20,  1.04s/it]
# Error processing store 포케올데이 숙대입구점: division by zero
# Processing Stores:  90%|████████▉ | 660/737 [11:42<01:21,  1.05s/it]
# Error processing store 포트리스 가산점: division by zero
# Processing Stores:  90%|████████▉ | 661/737 [11:44<01:21,  1.07s/it]
# Error processing store 포트리스 쌀국수 위례점: division by zero
# Processing Stores:  90%|████████▉ | 662/737 [11:45<01:21,  1.09s/it]
# Error processing store 포히엔 베트남 쌀국수: division by zero
# Processing Stores:  90%|████████▉ | 663/737 [11:46<01:21,  1.10s/it]
# Error processing store 폴베리: division by zero
# Processing Stores:  90%|█████████ | 664/737 [11:47<01:20,  1.10s/it]
# Error processing store 푸라닭 방학점: division by zero
# Processing Stores:  90%|█████████ | 665/737 [11:48<01:17,  1.08s/it]
# Error processing store 프랭크버거 개포동역점: division by zero
# Processing Stores:  90%|█████████ | 666/737 [11:49<01:14,  1.05s/it]
# Error processing store 프랭크버거 수락산역점: division by zero
# Processing Stores:  91%|█████████ | 667/737 [11:50<01:08,  1.03it/s]
# Error processing store 프랭크버거 용문시장점: division by zero
# Processing Stores:  91%|█████████ | 668/737 [11:51<01:08,  1.01it/s]
# Error processing store 프로마치 강남구청점: division by zero
# Processing Stores:  91%|█████████ | 669/737 [11:52<01:10,  1.03s/it]
# Error processing store 프롬하노이fromhanoi: division by zero
# Processing Stores:  91%|█████████ | 670/737 [11:53<01:11,  1.06s/it]
# Error processing store 프릭스(FREAX): division by zero
# Processing Stores:  91%|█████████ | 671/737 [11:54<01:09,  1.05s/it]
# Error processing store 플러피여의도점: division by zero
# Processing Stores:  91%|█████████ | 672/737 [11:54<00:56,  1.16it/s]
# Error processing store 플로어(FLORE): division by zero
# Processing Stores:  91%|█████████▏| 673/737 [11:56<00:59,  1.07it/s]
# Error processing store 피넘타이: division by zero
# Processing Stores:  91%|█████████▏| 674/737 [11:57<01:02,  1.00it/s]
# Error processing store 피에스타 타코&부리또: division by zero
# Processing Stores:  92%|█████████▏| 675/737 [11:57<00:55,  1.12it/s]
# Error processing store 피자스쿨 동대문역사점: division by zero
# Processing Stores:  92%|█████████▏| 676/737 [11:58<00:55,  1.10it/s]
# Error processing store 피자스톰 강남점: division by zero
# Processing Stores:  92%|█████████▏| 677/737 [11:59<00:55,  1.08it/s]
# Error processing store 피자의 생명은 치즈다(서울 본점): division by zero
# Processing Stores:  92%|█████████▏| 678/737 [12:00<00:58,  1.02it/s]
# Error processing store 피자헛 동덕여대본점: division by zero
# Processing Stores:  92%|█████████▏| 679/737 [12:01<00:59,  1.02s/it]
# Error processing store 필 가이즈: division by zero
# Processing Stores:  92%|█████████▏| 680/737 [12:02<00:57,  1.00s/it]
# Error processing store 하나바게트(hana baguette): division by zero
# Processing Stores:  92%|█████████▏| 681/737 [12:04<00:57,  1.03s/it]
# Error processing store 하노이 맥주밤거리 방이점: division by zero
# Processing Stores:  93%|█████████▎| 682/737 [12:05<00:58,  1.07s/it]
# Error processing store 하노이 맥주밤거리(신촌점): division by zero
# Processing Stores:  93%|█████████▎| 683/737 [12:06<00:57,  1.07s/it]
# Error processing store 하노이별 교대역점: division by zero
# Processing Stores:  93%|█████████▎| 684/737 [12:07<00:57,  1.09s/it]
# Error processing store 하노이별 망원점: division by zero
# Processing Stores:  93%|█████████▎| 685/737 [12:08<00:56,  1.10s/it]
# Error processing store 하노이별 서강대점: division by zero
# Processing Stores:  93%|█████████▎| 686/737 [12:09<00:56,  1.10s/it]
# Error processing store 하노이별 서울대입구점: division by zero
# Processing Stores:  93%|█████████▎| 687/737 [12:10<00:55,  1.10s/it]
# Error processing store 하노이별 서울숲점: division by zero
# Processing Stores:  93%|█████████▎| 688/737 [12:11<00:53,  1.09s/it]
# Error processing store 하노이별 약수점: division by zero
# Processing Stores:  93%|█████████▎| 689/737 [12:12<00:52,  1.09s/it]
# Error processing store 하노이쌀롱: division by zero
# Processing Stores:  94%|█████████▎| 690/737 [12:14<00:51,  1.10s/it]
# Error processing store 하노이의 아침: division by zero
# Processing Stores:  94%|█████████▍| 691/737 [12:15<00:50,  1.10s/it]
# Error processing store 하롱베이의 하루 시청점: division by zero
# Processing Stores:  94%|█████████▍| 692/737 [12:16<00:49,  1.11s/it]
# Error processing store 하이디라오 코엑스점: division by zero
# Processing Stores:  94%|█████████▍| 693/737 [12:17<00:48,  1.11s/it]
# Error processing store 하이카오산 화곡점: division by zero
# Processing Stores:  94%|█████████▍| 694/737 [12:18<00:47,  1.12s/it]
# Error processing store 하이퐁 가든: division by zero
# Processing Stores:  94%|█████████▍| 695/737 [12:19<00:46,  1.11s/it]
# Error processing store 한량면가: division by zero
# Processing Stores:  94%|█████████▍| 696/737 [12:20<00:43,  1.07s/it]
# Error processing store 할로인도네시아: division by zero
# Processing Stores:  95%|█████████▍| 697/737 [12:21<00:43,  1.09s/it]
# Error processing store 핫도그 앤 스프(HOTDOG & SOUP): division by zero
# Processing Stores:  95%|█████████▍| 698/737 [12:22<00:42,  1.10s/it]
# Error processing store 해방식당: division by zero
# Processing Stores:  95%|█████████▍| 699/737 [12:23<00:41,  1.10s/it]
# Error processing store 핸드파스타(Hand pasta): division by zero
# Processing Stores:  95%|█████████▍| 700/737 [12:25<00:40,  1.10s/it]
# Error processing store 행복은간장밥 신촌명물거리점: division by zero
# Processing Stores:  95%|█████████▌| 701/737 [12:26<00:40,  1.12s/it]
# Error processing store 허니비 서울(Honeybee Seoul): division by zero
# Processing Stores:  95%|█████████▌| 702/737 [12:27<00:39,  1.13s/it]
# Error processing store 헬로 브라질: division by zero
# Processing Stores:  95%|█████████▌| 703/737 [12:28<00:38,  1.13s/it]
# Error processing store 헬키푸키 선릉점: division by zero
# Processing Stores:  96%|█████████▌| 704/737 [12:29<00:37,  1.13s/it]
# Error processing store 헵시바극장: division by zero
# Processing Stores:  96%|█████████▌| 705/737 [12:30<00:36,  1.13s/it]
# Error processing store 현경 양고기: division by zero
# Processing Stores:  96%|█████████▌| 706/737 [12:31<00:34,  1.13s/it]
# Error processing store 호아빈군자역: division by zero
# Processing Stores:  96%|█████████▌| 707/737 [12:32<00:29,  1.02it/s]
# Error processing store 호아센포: division by zero
# Processing Stores:  96%|█████████▌| 708/737 [12:33<00:29,  1.02s/it]
# Error processing store 호앙비엣 서울역점: division by zero
# Processing Stores:  96%|█████████▌| 709/737 [12:34<00:29,  1.05s/it]
# Error processing store 호앙비엣 신논현점: division by zero
# Processing Stores:  96%|█████████▋| 710/737 [12:35<00:28,  1.07s/it]
# Error processing store 호앙비엣 을지로점: division by zero
# Processing Stores:  96%|█████████▋| 711/737 [12:36<00:28,  1.08s/it]
# Error processing store 호지보보: division by zero
# Processing Stores:  97%|█████████▋| 712/737 [12:37<00:24,  1.00it/s]
# Error processing store 호커보이(Hawker boy): division by zero
# Processing Stores:  97%|█████████▋| 713/737 [12:38<00:24,  1.03s/it]
# Error processing store 홀리차우 익스프레스: division by zero
# Processing Stores:  97%|█████████▋| 714/737 [12:39<00:22,  1.03it/s]
# Error processing store 홍대in파스타: division by zero
# Processing Stores:  97%|█████████▋| 715/737 [12:40<00:21,  1.03it/s]
# Error processing store 홍대쌀국수 논현점: division by zero
# Processing Stores:  97%|█████████▋| 716/737 [12:41<00:21,  1.02s/it]
# Error processing store 홍대쌀국수(롯데슈퍼마포점): division by zero
# Processing Stores:  97%|█████████▋| 717/737 [12:42<00:20,  1.05s/it]
# Error processing store 홍대쌀국수(목동점): division by zero
# Processing Stores:  97%|█████████▋| 718/737 [12:44<00:20,  1.08s/it]
# Error processing store 홍호아 동국대점: division by zero
# Processing Stores:  98%|█████████▊| 719/737 [12:45<00:19,  1.09s/it]
# Error processing store 홍호아 신촌점: division by zero
# Processing Stores:  98%|█████████▊| 720/737 [12:46<00:18,  1.10s/it]
# Error processing store 효뜨 강남점: division by zero
# Processing Stores:  98%|█████████▊| 721/737 [12:47<00:17,  1.11s/it]
# Error processing store 효이당: division by zero
# Processing Stores:  98%|█████████▊| 722/737 [12:48<00:14,  1.00it/s]
# Error processing store 후르레스토랑: division by zero
# Processing Stores:  98%|█████████▊| 723/737 [12:49<00:14,  1.00s/it]
# Error processing store 후안타이: division by zero
# Processing Stores:  98%|█████████▊| 724/737 [12:50<00:13,  1.04s/it]
# Error processing store 후암쌀국수: division by zero
# Processing Stores:  98%|█████████▊| 725/737 [12:51<00:12,  1.07s/it]
# Error processing store 후투타코: division by zero
# Processing Stores:  99%|█████████▊| 726/737 [12:52<00:11,  1.09s/it]
# Error processing store 훅트포케 건대 롯데시네마점: division by zero
# Processing Stores:  99%|█████████▊| 727/737 [12:53<00:10,  1.08s/it]
# Error processing store 훅트포케 공덕 효창공원점: division by zero
# Processing Stores:  99%|█████████▉| 728/737 [12:54<00:09,  1.10s/it]
# Error processing store 훅트포케 광화문점: division by zero
# Processing Stores:  99%|█████████▉| 729/737 [12:55<00:08,  1.11s/it]
# Error processing store 훅트포케 목동점: division by zero
# Processing Stores:  99%|█████████▉| 730/737 [12:56<00:06,  1.04it/s]
# Error processing store 훅트포케(신용산점): division by zero
# Processing Stores:  99%|█████████▉| 731/737 [12:57<00:06,  1.01s/it]
# Error processing store 훅트포케(양재점): division by zero
# Processing Stores:  99%|█████████▉| 732/737 [12:58<00:04,  1.05it/s]
# Error processing store 훈장소주관: division by zero
# Processing Stores:  99%|█████████▉| 733/737 [12:59<00:03,  1.03it/s]
# Error processing store 휘슬 버드(WHISTLE BIRD): division by zero
# Processing Stores: 100%|█████████▉| 734/737 [13:00<00:03,  1.01s/it]
# Error processing store 흐리마리: division by zero
# Processing Stores: 100%|█████████▉| 735/737 [13:01<00:02,  1.01s/it]
# Error processing store 흑석호치민: division by zero
# Processing Stores: 100%|█████████▉| 736/737 [13:02<00:01,  1.04s/it]
# Error processing store 히타나: division by zero
# Processing Stores: 100%|██████████| 737/737 [13:03<00:00,  1.06s/it]
# Error processing store 힛힛: division by zero
# Results saved to 20240830_191143_store_review_summaries.csv and 20240830_191143_store_sentiments.csv
